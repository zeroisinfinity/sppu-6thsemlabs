# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')
sns.__version__
dataset = sns.load_dataset("iris")
dataset = pd.read_csv('iris/iris.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_194/1868789819.py in <cell line: 0>()
#       8 sns.__version__
#       9 dataset = sns.load_dataset("iris")
# ---> 10 dataset = pd.read_csv('iris/iris.csv')
#
# ...

# %%
dataset

# %%
dataset1 = sns.load_dataset("iris")
dataset.columns = dataset1.columns

# %%
dataset.head()

# %%
dataset.info()

# %%
dataset.shape

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(20,10))
sns.histplot(data=dataset,x='sepal_length',hue='species'
             ,kde=True,palette='Set1',multiple='stack')
plt.title('Sepal len')
plt.show()

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(20,10))
sns.histplot(data=dataset,x='sepal_width',hue='species'
             ,kde=True,palette='Set1',multiple='stack')
plt.title('Sepal len')
plt.show()

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(20,10))
sns.histplot(data=dataset,x='petal_length',hue='species'
             ,kde=True,palette='Set1',multiple='stack')
plt.title('Sepal len')
plt.show()

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(20,10))
sns.histplot(data=dataset,x='petal_width',hue='species'
             ,kde=True,palette='Set1',multiple='stack')
plt.title('Sepal len')
plt.show()

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(20,10))
sns.boxplot(data=dataset,y='sepal_length',x='species' ,
            palette='Set1')
plt.title('Sepal len box plot')
plt.show()

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(20,10))
sns.boxplot(data=dataset,y='sepal_width',x='species' ,
            palette='Set1')
plt.title('Sepal len box plot')
plt.show()

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(20,10))
sns.boxplot(data=dataset,y='petal_length',x='species' ,
            palette='Set1')
plt.title('Sepal len box plot')
plt.show()

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(20,10))
sns.boxplot(data=dataset,y='petal_width',x='species' ,
            palette='Set1')
plt.title('Sepal len box plot')
plt.show()
