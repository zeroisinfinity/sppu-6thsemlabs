# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pl
import seaborn as sns

# %%
df = pd.read_csv('HousingData.csv')
display(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv('HousingData.csv')
#       2 display(df)
#
# File ~/sppu-labs/DSBDAL/LAB-PRAC/python-prac/asgn-1/jupyter_env/lib/python3.12/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~/sppu-labs/DSBDAL/LAB-PRAC/python-prac/asgn-1/jupyter_env/lib/python3.12/site-packages/pandas/io/parsers/readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~/sppu-labs/DSBDAL/LAB-PRAC/python-prac/asgn-1/jupyter_env/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~/sppu-labs/DSBDAL/LAB-PRAC/python-prac/asgn-1/jupyter_env/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~/sppu-labs/DSBDAL/LAB-PRAC/python-prac/asgn-1/jupyter_env/lib/python3.12/site-packages/pandas/io/common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'HousingData.csv'

# %%
df.head()

# %%
df.tail()

# %%
df.info()

# %%
df.describe()

# %%
df.columns

# %%
df.dtypes

# %%
df.keys()

# %%
df.dropna(inplace=True)
df

# %%
#x = pd.DataFrame(np.c_[df['lstat'] , df['rm']],columns=['lstat','rm'])
x = df.drop('MEDV',axis=1)
y = df['MEDV']

# %%
x

# %%
y

# %%
x.shape

# %%
from sklearn.model_selection import train_test_split
xtrain , xtest , ytrain , ytest = train_test_split(x,y,
                                                   random_state=0,
                                                   train_size=0.25)

# %%
xtrain

# %%
xtrain.shape

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()

# %%
regressor.fit(xtrain,ytrain)

# %%
regressor.coef_

# %%
regressor.intercept_

# %%
y_pred = regressor.predict(xtest)

# %%
y_pred

# %%
y_pred.shape

# %%
result = pd.DataFrame({'Actual' : ytest , 'Predicted' : y_pred})
result

# %%
residual_err = abs(ytest - y_pred)
residual_err

# %%
sum(residual_err)/len(residual_err)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(ytest,y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(ytest,y_pred)

# %%
regressor.score(xtest,ytest)

# %%
from sklearn.metrics import r2_score
r2_score(ytest,y_pred)

# %%
new = [[.658,0,8.7584,0,0.757,5.742387,69.5,3.587,4,307,22,49.99,11.4]]
new_data = {k : v for k,v in zip(xtrain.columns,*new)}
df_new = pd.DataFrame(new_data,index=pd.interval_range(start=0,end=len(new)))

# %%
regressor.predict(df_new)
