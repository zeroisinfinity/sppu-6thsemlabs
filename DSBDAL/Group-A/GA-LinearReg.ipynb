# %%
from unittest.mock import inplace

import numpy as np
import pandas as pd
import matplotlib.pyplot as pl
import seaborn as sns

# %%
df = pd.read_csv('HousingData.csv')
display(df)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
df.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273     21.0
#
#           B  LSTAT  MEDV
# 501  391.99    NaN  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
df.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX          int64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %%
df.keys()
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
df.dropna(inplace=True)
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 5    0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 499  0.17783   0.0   9.69   0.0  0.585  5.569  73.5  2.3999    6  391
# 500  0.22438   0.0   9.69   0.0  0.585  6.027  79.7  2.4982    6  391
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
#x = pd.DataFrame(np.c_[df['lstat'] , df['rm']],columns=['lstat','rm'])
x = df.drop('MEDV',axis=1)
y = df['MEDV']

# %%
x
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 5    0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 499  0.17783   0.0   9.69   0.0  0.585  5.569  73.5  2.3999    6  391
# 500  0.22438   0.0   9.69   0.0  0.585  6.027  79.7  2.4982    6  391
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# ...

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 5      28.7
#        ...
# 499    17.5
# 500    16.8
# 502    20.6
# 503    23.9
# 504    22.0
# Name: MEDV, Length: 394, dtype: float64

# %%
x.shape
# Out:
# (394, 13)

# %%
from sklearn.model_selection import train_test_split
xtrain , xtest , ytrain , ytest = train_test_split(x,y,
                                                   random_state=0,
                                                   train_size=0.25)

# %%
xtrain
# Out:
#          CRIM     ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 476   4.87141    0.0  18.10   0.0  0.614  6.484   93.6  2.3053   24  666
# 114   0.14231    0.0  10.01   0.0  0.547  6.254   84.2  2.2565    6  432
# 491   0.10574    0.0  27.74   0.0  0.609  5.983   98.8  1.8681    4  711
# 225   0.52693    0.0   6.20   0.0  0.504  8.725   83.0  2.8944    8  307
# 328   0.06617    0.0   3.24   0.0  0.460  5.868   25.8  5.2146    4  430
# ..        ...    ...    ...   ...    ...    ...    ...     ...  ...  ...
# 415  18.08460    0.0  18.10   0.0  0.679  6.434  100.0  1.8347   24  666
# 248   0.16439   22.0   5.86   0.0  0.431  6.433   49.1  7.8265    7  330
# 141   1.62864    0.0  21.89   0.0  0.624  5.019  100.0  1.4394    4  437
# 57    0.01432  100.0   1.32   0.0  0.411  6.816   40.5  8.3248    5  256
# 218   0.11069    0.0  13.89   1.0  0.550  5.951   93.8  2.8893    5  276
#
#      PTRATIO       B  LSTAT
# 476     20.2  396.21  18.68
# 114     17.8  388.74  10.45
# ...

# %%
xtrain.shape
# Out:
# (98, 13)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()

# %%
regressor.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
regressor.coef_
# Out:
# array([ 1.75975218e-01,  7.77147682e-02,  2.60419256e-01,  6.33846719e+00,
#        -2.93061382e+01,  5.82729546e+00, -5.37263281e-02, -1.90814475e+00,
#         2.22346169e-01, -1.84787607e-02, -6.90415273e-01,  2.16025588e-02,
#        -2.14000514e-01])

# %%
regressor.intercept_
# Out:
# np.float64(22.082718741685742)

# %%
y_pred = regressor.predict(xtest)

# %%
y_pred
# Out:
# array([18.13421236, 18.28733097, 26.87837986, 43.56379343, 15.92755481,
#        18.86949427, 30.52886468, 18.8454982 , 28.63092191, 13.80088065,
#        22.81920539, 14.56838531, 23.50123077, 26.44263288,  7.8511206 ,
#        33.24047581, 27.30102889, 28.87927318, 25.06698774, 28.97400458,
#        18.89930863, 31.00124269, 20.95113574, 19.22140024, 19.99894217,
#        23.44632338, 20.87698289, 25.94521905, 23.96560489, 25.15405914,
#         4.72826494, 27.01642978, 18.07773051, 26.34296027, 15.8532341 ,
#        15.53025731, 22.35979007, 17.58849618, 22.53400917, 12.4374363 ,
#        24.18575233, 14.37704968, 32.79538269, 22.88844748, 34.1081181 ,
#        13.26891517, 21.72014732, 17.32507934,  9.98582497, 16.46063827,
#        19.83451052, 18.43444927, 12.45520486, 34.1586355 , 20.76429967,
#        21.44965762, 18.6407481 , 17.60168441, 21.13549763, 28.60903074,
#        17.7075007 , 19.85533163, 21.01455154, 18.5676957 , 21.72916782,
# ...

# %%
y_pred.shape
# Out:
# (296,)

# %%
result = pd.DataFrame({'Actual' : ytest , 'Predicted' : y_pred})
result
# Out:
#      Actual  Predicted
# 136    17.4  18.134212
# 360    25.0  18.287331
# 81     23.9  26.878380
# 195    50.0  43.563793
# 421    14.2  15.927555
# ..      ...        ...
# 242    22.2  23.937002
# 27     14.8  14.211394
# 52     25.0  28.376194
# 0      24.0  27.022374
# 258    36.0  33.441242
#
# [296 rows x 2 columns]

# %%
residual_err = abs(ytest - y_pred)
residual_err
# Out:
# 136    0.734212
# 360    6.712669
# 81     2.978380
# 195    6.436207
# 421    1.727555
#          ...
# 242    1.737002
# 27     0.588606
# 52     3.376194
# 0      3.022374
# 258    2.558758
# Name: MEDV, Length: 296, dtype: float64

# %%
sum(residual_err)/len(residual_err)
# Out:
# 3.858015766723094

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(ytest,y_pred)
# Out:
# 3.8580157667230948

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(ytest,y_pred)
# Out:
# 0.22758755777607692

# %%
regressor.score(xtest,ytest)
# Out:
# 0.6316244536004998

# %%
from sklearn.metrics import r2_score
r2_score(ytest,y_pred)
# Out:
# 0.6316244536004998

# %%
new = [[.658,0,8.7584,0,0.757,5.742387,69.5,3.587,4,307,22,49.99,11.4]]
new_data = {k : v for k,v in zip(xtrain.columns,*new)}
df_new = pd.DataFrame(new_data,index=pd.interval_range(start=0,end=len(new)))

# %%
regressor.predict(df_new)
# Out:
# array([3.84628572])
